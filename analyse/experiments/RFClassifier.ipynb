# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
import pickle
import logging

import utils.download_db as ddb
from utils.global_config import CONFIG

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
logging.basicConfig(
    filename='run-logs.log', 
    encoding='utf-8', 
    format='%(asctime)s %(levelname)s: %(message)s',
    level=logging.DEBUG, 
    filemode='w'
)

# %% [markdown]
# # Get model

# %%
model_filename = r'../models/RFClassifier.pickle'
with open(model_filename, 'rb') as bin_file:
    model = pickle.load(bin_file)

# %% [markdown]
# # Download database №1

# %%
url = "https://physionet.org/static/published-projects/afdb/mit-bih-atrial-fibrillation-database-1.0.0.zip"
name = "MIT-BIH-AtrialFibrillation"

db_path = ddb.get_db(url, name, "../../analyse/data/")

signals = ddb.get_signals(db_path, reload=False)

# %%
windows = []
classification = []
for sig in signals:
    for window in sig.windows:
        metrics, has_defect = window.get_data()
        windows.append(metrics)
        classification.append(has_defect)

windows_pd = pd.DataFrame(windows)
classification_pd = pd.DataFrame(classification)

# %%
windows_pd
# Out:
#            median      mean    variance  mean_abs        max       min  \
# 0       -0.002326  0.055419    0.099190  0.222344   0.923729 -0.420833
# 1       -0.004695  0.038917    0.093349  0.207399   0.923729 -0.420833
# 2       -0.004695  0.040613    0.091894  0.205703   0.923729 -0.420833
# 3       -0.004695  0.038467    0.091732  0.203557   0.923729 -0.420833
# 4       -0.004785  0.015771    0.082734  0.188534   0.923729 -0.420833
# ...           ...       ...         ...       ...        ...       ...
# 2294577 -0.224906  2.857417  155.126511  3.605519  61.406250 -1.000000
# 2294578 -0.236220  2.727775  149.324823  3.476644  61.406250 -1.000000
# 2294579 -0.213592  5.590630  328.090512  6.307107  71.166466 -1.000000
# 2294580 -0.236220  5.551042  328.571580  6.346694  71.166466 -1.000000
# 2294581 -0.224906  5.824002  340.399382  6.569473  71.166466 -1.000000
#
#                 sum  AAA  AAB  AAC  ...  BCC  CAA  CAB  CAC  CBA  CBB  CBC  \
# 0          1.662562    4    0    2  ...    0    2    0    0    1    4    0
# 1          1.167500    5    0    2  ...    0    2    0    0    1    4    0
# 2          1.218393    5    0    3  ...    0    2    0    0    1    3    0
# 3          1.154017    5    0    3  ...    0    2    0    0    1    3    0
# 4          0.473120    5    0    3  ...    0    2    0    1    1    3    0
# ...             ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2294577   68.578016    0    0    0  ...    2    0    1    1    0    2    2
# 2294578   68.194373    0    0    0  ...    2    0    1    1    0    2    2
# 2294579  139.765746    0    0    0  ...    2    0    1    0    0    2    2
# 2294580  138.776056    0    0    0  ...    2    0    1    0    0    2    3
# 2294581  139.776056    0    0    0  ...    2    0    1    0    0    2    3
#
#          CCA  CCB  CCC
# 0          0    0    0
# 1          0    0    0
# 2          0    0    0
# 3          0    0    0
# 4          0    0    0
# ...      ...  ...  ...
# 2294577    1    2    5
# 2294578    1    2    5
# 2294579    1    2    5
# 2294580    1    2    5
# 2294581    1    2    4
#
# [2294582 rows x 34 columns]

# %%
classification_pd
# Out:
#              0
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 2294577   True
# 2294578   True
# 2294579   True
# 2294580   True
# 2294581   True
#
# [2294582 rows x 1 columns]

# %% [markdown]
# # Tests

# %% [markdown]
# **Random**

# %%
results = pd.DataFrame()

for i in range(100):
    _, X_test, _, y_test = train_test_split(windows_pd, classification_pd, train_size=0.9, random_state=i)
    y_pred = model.predict(X_test)
    f1 = f1_score(y_test, y_pred)
    result = model.score(X_test, y_test)
    df = pd.DataFrame({"score" : result, "error" : 1 - result, "f1 norm" : f1}, index=[i])
    results = pd.concat([results, df])

# %%
results
# Out:
#        score     error   f1 norm
# 0   0.986668  0.013332  0.953886
# 1   0.986621  0.013379  0.953159
# 2   0.986623  0.013377  0.953450
# 3   0.986487  0.013513  0.953509
# 4   0.986710  0.013290  0.953405
# ..       ...       ...       ...
# 95  0.986625  0.013375  0.952847
# 96  0.986508  0.013492  0.953097
# 97  0.986310  0.013690  0.952542
# 98  0.986768  0.013232  0.953500
# 99  0.986449  0.013551  0.952902
#
# [100 rows x 3 columns]

# %%
print("mean score:\t", np.mean(results["score"]))
print("min score:\t", np.min(results["score"]))
print("max score:\t", np.max(results["score"]))
print("mean f1 norm:\t", np.mean(results["f1 norm"]))
# Out:
# mean score:	 0.9866175007773598
# min score:	 0.9861429172211156
# max score:	 0.9870441299999746
# mean f1 norm:	 0.9532576514229788

# %% [markdown]
# **Test all signals**

# %%
results = pd.DataFrame()

for i, signal in enumerate(signals):
    X_test, y_test = signal.get_data()
    y_pred = model.predict(X_test)
    f1 = f1_score(y_test, y_pred)
    result = accuracy_score(y_test, y_pred)
    df = pd.DataFrame({"score" : result, "error" : 1 - result, "f1 norm" : f1}, index=[i])
    results = pd.concat([results, df])

# %%
results
# Out:
#        score     error   f1 norm
# 0   0.928788  0.071212  0.291406
# 1   0.938198  0.061802  0.325639
# 2   0.942716  0.057284  0.889768
# 3   0.942639  0.057361  0.890051
# 4   0.992323  0.007677  0.855936
# 5   0.990338  0.009662  0.825540
# 6   0.944603  0.055397  0.742415
# 7   0.939100  0.060900  0.722986
# 8   0.994374  0.005626  0.995572
# 9   0.994609  0.005391  0.995729
# 10  0.983220  0.016780  0.919449
# 11  0.981977  0.018023  0.913910
# 12  0.796932  0.203068  0.869868
# 13  0.804172  0.195828  0.875130
# 14  0.982870  0.017130  0.372000
# 15  0.992995  0.007005  0.590062
# 16  0.947779  0.052221  0.960504
# 17  0.942987  0.057013  0.957179
# 18  0.969462  0.030538  0.612401
# 19  0.966059  0.033941  0.583290
# 20  0.979699  0.020301  0.989628
# 21  0.979714  0.020286  0.989642
# 22  0.990049  0.009951  0.713344
# 23  0.990447  0.009553  0.729048
# 24  0.884845  0.115155  0.896753
# 25  0.878839  0.121161  0.892795
# 26  0.995921  0.004079  0.997956
# 27  0.986259  0.013741  0.993082
# 28  0.990696  0.009304  0.995326
# 29  0.990697  0.009303  0.995327
# 30  0.980975  0.019025  0.986415
# 31  0.980220  0.019780  0.985894
# 32  0.980269  0.019731  0.956379
# 33  0.979112  0.020888  0.953828
# 34  0.992931  0.007069  0.995408
# 35  0.993338  0.006662  0.995676
# 36  0.866815  0.133185  0.783168
# 37  0.886740  0.113260  0.808884
# 38  0.912313  0.087687  0.846741
# 39  0.912118  0.087882  0.846279
# 40  0.994882  0.005118  0.996699
# 41  0.996986  0.003014  0.998048
# 42  0.990351  0.009649  0.922926
# 43  0.988539  0.011461  0.909656
# 44  0.998436  0.001564  0.998952
# 45  0.998795  0.001205  0.999191

# %%
print("mean score:\t", np.mean(results["score"]))
print("min score:\t", np.min(results["score"]))
print("mean f1 norm:\t", np.mean(results["f1 norm"]))
# Out:
# mean score:	 0.958611395338953
# min score:	 0.7969320804783628
# mean f1 norm:	 0.8557799651971602

# %% [markdown]
# # Download database №2

# %%
url = "https://physionet.org/static/published-projects/vfdb/mit-bih-malignant-ventricular-ectopy-database-1.0.0.zip"
name = "MIT-BIH-Malignant-Ventricular-Ectopy"

db_path = ddb.get_db(url, name, "../../analyse/data/")

signals = ddb.get_signals(db_path, reload=False)

# %%
windows = []
classification = []
for sig in signals:
    for window in sig.windows:
        metrics, has_defect = window.get_data()
        windows.append(metrics)
        classification.append(has_defect)

windows_pd = pd.DataFrame(windows)
classification_pd = pd.DataFrame(classification)

# %%
windows_pd
# Out:
#           median      mean  variance  mean_abs       max       min       sum  \
# 0      -0.042558  0.110940  0.314108  0.389761  1.261905 -0.413043  3.328204
# 1      -0.021796  0.122727  0.306837  0.377974  1.261905 -0.413043  3.681810
# 2      -0.021796  0.082418  0.262118  0.337665  1.259259 -0.413043  2.472537
# 3      -0.021796  0.090877  0.257901  0.329206  1.259259 -0.413043  2.726296
# 4      -0.032246  0.076556  0.266664  0.343527  1.259259 -0.437037  2.296667
# ...          ...       ...       ...       ...       ...       ...       ...
# 137633  0.029740  0.144267  0.373776  0.458281  1.949367 -0.658747  4.328006
# 137634 -0.048210  0.124958  0.378138  0.456837  1.949367 -0.658747  3.748738
# 137635  0.029740  0.153716  0.374756  0.462206  1.949367 -0.658747  4.611483
# 137636  0.029740  0.152094  0.376591  0.463828  1.949367 -0.658747  4.562824
# 137637  0.029740  0.107266  0.318526  0.419000  1.949367 -0.658747  3.217984
#
#         AAA  AAB  AAC  ...  BCC  CAA  CAB  CAC  CBA  CBB  CBC  CCA  CCB  CCC
# 0         3    0    2  ...    3    3    1    0    0    0    6    0    3    0
# 1         4    0    2  ...    3    3    1    0    0    0    5    0    3    0
# 2         5    0    2  ...    3    3    1    0    0    0    5    0    3    0
# 3         6    0    2  ...    3    2    1    0    0    0    5    0    3    0
# 4         5    0    3  ...    3    2    1    0    0    0    5    0    3    0
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 137633    0    0    0  ...    3    0    0    0    0    4    4    0    5    0
# 137634    0    0    0  ...    2    0    0    0    0    4    5    0    5    0
# 137635    0    0    0  ...    2    0    0    0    0    4    5    0    4    0
# 137636    0    0    0  ...    2    0    0    0    0    4    5    0    4    0
# 137637    0    0    0  ...    2    0    0    0    0    4    5    0    4    0
#
# [137638 rows x 34 columns]

# %%
classification_pd
# Out:
#             0
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 137633   True
# 137634   True
# 137635   True
# 137636   True
# 137637   True
#
# [137638 rows x 1 columns]

# %% [markdown]
# # Tests

# %% [markdown]
# **Random**

# %%
results = pd.DataFrame()

for i in range(100):
    _, X_test, _, y_test = train_test_split(windows_pd, classification_pd, train_size=0.9, random_state=i)
    y_pred = model.predict(X_test)
    f1 = f1_score(y_test, y_pred)
    result = model.score(X_test, y_test)
    df = pd.DataFrame({"score" : result, "error" : 1 - result, "f1 norm" : f1}, index=[i])
    results = pd.concat([results, df])

# %%
results
# Out:
#        score     error   f1 norm
# 0   0.690940  0.309060  0.757051
# 1   0.691449  0.308551  0.761166
# 2   0.686737  0.313263  0.752904
# 3   0.687367  0.312633  0.755533
# 4   0.691401  0.308599  0.757090
# ..       ...       ...       ...
# 95  0.682444  0.317556  0.752748
# 96  0.677773  0.322227  0.750295
# 97  0.696484  0.303516  0.762852
# 98  0.682656  0.317344  0.750085
# 99  0.676896  0.323104  0.751673
#
# [100 rows x 3 columns]

# %%
print("mean score:\t", np.mean(results["score"]))
print("min score:\t", np.min(results["score"]))
print("max score:\t", np.max(results["score"]))
print("mean f1 norm:\t", np.mean(results["f1 norm"]))
# Out:
# mean score:	 0.6846244652800024
# min score:	 0.6717668834654618
# max score:	 0.6977442078066911
# mean f1 norm:	 0.7550256692753814

# %% [markdown]
# **Test all siganls**

# %%
results = pd.DataFrame()

for i, signal in enumerate(signals):
    X_test, y_test = signal.get_data()
    y_pred = model.predict(X_test)
    f1 = f1_score(y_test, y_pred)
    result = accuracy_score(y_test, y_pred)
    df = pd.DataFrame({"score" : result, "error" : 1 - result, "f1 norm" : f1}, index=[i])
    results = pd.concat([results, df])

# %%
results
# Out:
#        score     error   f1 norm
# 0   0.770296  0.229704  0.731265
# 1   0.763987  0.236013  0.724327
# 2   0.803219  0.196781  0.847362
# 3   0.796740  0.203260  0.835709
# 4   0.629416  0.370584  0.462826
# 5   0.619375  0.380625  0.734997
# 6   0.703374  0.296626  0.673689
# 7   0.701629  0.298371  0.675879
# 8   0.872179  0.127821  0.872276
# 9   0.754794  0.245206  0.386108
# 10  0.953373  0.046627  0.958438
# 11  0.952193  0.047807  0.964145
# 12  0.239069  0.760931  0.305221
# 13  0.240145  0.759855  0.307001
# 14  0.563825  0.436175  0.663626
# 15  0.553988  0.446012  0.664471
# 16  0.945261  0.054739  0.963153
# 17  0.958254  0.041746  0.972136
# 18  0.991688  0.008312  0.994912
# 19  0.993662  0.006338  0.996211
# 20  0.210607  0.789393  0.347937
# 21  0.192474  0.807526  0.322814
# 22  0.203631  0.796369  0.338362
# 23  0.216360  0.783640  0.355749
# 24  0.817483  0.182517  0.899577
# 25  0.805029  0.194971  0.891984
# 26  0.357532  0.642468  0.526263
# 27  0.416145  0.583855  0.585206
# 28  0.854212  0.145788  0.921374
# 29  0.843445  0.156555  0.915075
# 30  0.180723  0.819277  0.306122
# 31  0.192371  0.807629  0.322669
# 32  0.842640  0.157360  0.885686
# 33  0.840547  0.159453  0.883489
# 34  0.772139  0.227861  0.792007
# 35  0.827522  0.172478  0.843789
# 36  0.597996  0.402004  0.748432
# 37  0.594443  0.405557  0.745643
# 38  0.915534  0.084466  0.904784
# 39  0.920228  0.079772  0.910909
# 40  0.789840  0.210160  0.857143
# 41  0.782955  0.217045  0.850589
# 42  0.988439  0.011561  0.994186
# 43  0.988498  0.011502  0.994216

# %%
print("mean score:\t", np.mean(results["score"]))
print("min score:\t", np.min(results["score"]))
print("mean f1 norm:\t", np.mean(results["f1 norm"]))
# Out:
# mean score:	 0.6808468080273133
# min score:	 0.18072289156626506
# mean f1 norm:	 0.7244945748641206

# %% [markdown]
# # Test all signals at once

# %%
signals = ddb.get_all_signals()

# %%
results = pd.DataFrame()

for i, signal in enumerate(signals):
    X_test, y_test = signal.get_data()
    y_pred = model.predict(X_test)
    f1 = f1_score(y_test, y_pred)
    result = accuracy_score(y_test, y_pred)
    df = pd.DataFrame({"score" : result, "error" : 1 - result, "f1 norm" : f1}, index=[i])
    results = pd.concat([results, df])

# %%
results
# Out:
#        score     error   f1 norm
# 0   0.928788  0.071212  0.291406
# 1   0.938198  0.061802  0.325639
# 2   0.942716  0.057284  0.889768
# 3   0.942639  0.057361  0.890051
# 4   0.992323  0.007677  0.855936
# ..       ...       ...       ...
# 85  0.920228  0.079772  0.910909
# 86  0.789840  0.210160  0.857143
# 87  0.782955  0.217045  0.850589
# 88  0.988439  0.011561  0.994186
# 89  0.988498  0.011502  0.994216
#
# [90 rows x 3 columns]

# %%
print("mean score:\t", np.mean(results["score"]))
print("min score:\t", np.min(results["score"]))
print("mean f1 norm:\t", np.mean(results["f1 norm"]))
# Out:
# mean score:	 0.822815374875485
# min score:	 0.18072289156626506
# mean f1 norm:	 0.7915959965898963
